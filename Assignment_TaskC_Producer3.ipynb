# %%
# Import statements
import socket
import sys
import time
import random
import datetime
import csv
from time import strftime
from time import sleep
from json import dumps
from kafka import KafkaProducer


def publish_message(producer_instance, topic_name, data):
    try:
        value_bytes = bytes(data, encoding='utf-8')
        producer_instance.send(topic_name, value=value_bytes)
        print('Message published successfully. ' + data)
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['127.0.0.1:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer

climate_streaming = csv.reader(open('hotspot_TERRA_streaming.csv', "r"))
climate_header = []
collection = []
is_header = True


# Wait for a connection
print('['+ str(datetime.datetime.now())+'] Waiting for a connection...')
    

if __name__ == '__main__':
   
    topic = 'Producer3'
    Producer3 = connect_kafka_producer()

while True:
    for row_climate in climate_streaming:
        if is_header:
                for i in range(len(row_climate)):
                    climate_header.append(row_climate[i].strip())
                is_header = False
                continue
        else:
            record_climate = {}
            date_time = datetime.datetime.now().strftime("%Y-%m-%dT%H:%M:%S")
            record_climate['Datetime'] = date_time
            record_climate['Senderid'] = 'TERRA'
            for i in range(len(row_climate)):
                try:
                    record_climate[climate_header[i]] = int(row_climate[i].strip())
                except ValueError:
                    try:
                        record_climate[climate_header[i]] = float(row_climate[i].strip())
                    except ValueError:
                        record_climate[climate_header[i]] = row_climate[i].strip()
            data = str(record_climate)
            collection.append(data)

            


    number = random.randint(10,30)
    data = collection[random.randrange(len(collection))]
    publish_message(Producer3, topic, data)
    time.sleep(number)
# Out:
# [2019-05-24 15:46:13.821247] Waiting for a connection...
# Message published successfully. {'surface_temperature_celcius': 61, 'latitude': -36.6936, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 86, 'longitude': 145.2788}
# Message published successfully. {'surface_temperature_celcius': 50, 'latitude': -38.1758, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 67, 'longitude': 144.489}
# Message published successfully. {'surface_temperature_celcius': 45, 'latitude': -36.3012, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 70, 'longitude': 141.163}
# Message published successfully. {'surface_temperature_celcius': 104, 'latitude': -37.853, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 94, 'longitude': 142.5253}
# Message published successfully. {'surface_temperature_celcius': 41, 'latitude': -37.9538, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 62, 'longitude': 143.1487}
# Message published successfully. {'surface_temperature_celcius': 57, 'latitude': -36.5507, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 83, 'longitude': 142.5788}
# Message published successfully. {'surface_temperature_celcius': 46, 'latitude': -36.7791, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 72, 'longitude': 141.5711}
# Message published successfully. {'surface_temperature_celcius': 40, 'latitude': -36.8679, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 59, 'longitude': 142.7328}
# Message published successfully. {'surface_temperature_celcius': 55, 'latitude': -36.9664, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 81, 'longitude': 142.1561}
# Message published successfully. {'surface_temperature_celcius': 42, 'latitude': -37.0484, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 52, 'longitude': 141.6245}
# Message published successfully. {'surface_temperature_celcius': 121, 'latitude': -37.017, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 100, 'longitude': 148.1297}
# Message published successfully. {'surface_temperature_celcius': 40, 'latitude': -36.6363, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 54, 'longitude': 144.3033}
# Message published successfully. {'surface_temperature_celcius': 60, 'latitude': -36.6072, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 86, 'longitude': 145.2651}
# Message published successfully. {'surface_temperature_celcius': 53, 'latitude': -37.368, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 79, 'longitude': 148.05}
# Message published successfully. {'surface_temperature_celcius': 54, 'latitude': -36.3066, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 81, 'longitude': 141.0728}
# Message published successfully. {'surface_temperature_celcius': 64, 'latitude': -37.976, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 88, 'longitude': 145.649}
# Message published successfully. {'surface_temperature_celcius': 76, 'latitude': -37.224, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 95, 'longitude': 147.4347}
# Message published successfully. {'surface_temperature_celcius': 47, 'latitude': -37.9029, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 73, 'longitude': 143.5946}
# Message published successfully. {'surface_temperature_celcius': 82, 'latitude': -38.2375, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 98, 'longitude': 142.8363}
# Message published successfully. {'surface_temperature_celcius': 39, 'latitude': -36.4147, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 56, 'longitude': 141.0669}
# Message published successfully. {'surface_temperature_celcius': 40, 'latitude': -37.0459, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 58, 'longitude': 142.7207}
# Message published successfully. {'surface_temperature_celcius': 68, 'latitude': -36.7751, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 91, 'longitude': 145.1696}
# Message published successfully. {'surface_temperature_celcius': 52, 'latitude': -36.6664, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 79, 'longitude': 145.2554}
# Message published successfully. {'surface_temperature_celcius': 86, 'latitude': -37.7236, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 99, 'longitude': 143.3995}
# Message published successfully. {'surface_temperature_celcius': 86, 'latitude': -37.7236, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 99, 'longitude': 143.3995}
# Message published successfully. {'surface_temperature_celcius': 46, 'latitude': -37.7496, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 64, 'longitude': 148.3898}
# Message published successfully. {'surface_temperature_celcius': 64, 'latitude': -36.9413, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 89, 'longitude': 142.9777}
# Message published successfully. {'surface_temperature_celcius': 42, 'latitude': -36.3115, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 65, 'longitude': 143.3581}
# Message published successfully. {'surface_temperature_celcius': 46, 'latitude': -37.586, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 80, 'longitude': 141.271}
# Message published successfully. {'surface_temperature_celcius': 66, 'latitude': -36.5399, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 90, 'longitude': 144.678}
# Message published successfully. {'surface_temperature_celcius': 45, 'latitude': -36.7038, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 70, 'longitude': 141.8813}
# Message published successfully. {'surface_temperature_celcius': 74, 'latitude': -36.3966, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 94, 'longitude': 141.406}
# Message published successfully. {'surface_temperature_celcius': 45, 'latitude': -36.778, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 69, 'longitude': 145.1635}
# Message published successfully. {'surface_temperature_celcius': 54, 'latitude': -38.0812, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 80, 'longitude': 143.2335}
# Message published successfully. {'surface_temperature_celcius': 42, 'latitude': -37.461, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 76, 'longitude': 148.105}
# Message published successfully. {'surface_temperature_celcius': 43, 'latitude': -36.3269, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 67, 'longitude': 144.0871}
# Message published successfully. {'surface_temperature_celcius': 57, 'latitude': -36.1574, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 83, 'longitude': 141.7206}
# Message published successfully. {'surface_temperature_celcius': 39, 'latitude': -37.8387, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 53, 'longitude': 144.6301}
# Message published successfully. {'surface_temperature_celcius': 67, 'latitude': -37.5788, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 90, 'longitude': 148.592}
# Message published successfully. {'surface_temperature_celcius': 82, 'latitude': -37.618, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 98, 'longitude': 143.0013}
# Message published successfully. {'surface_temperature_celcius': 58, 'latitude': -36.3606, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 84, 'longitude': 144.498}
# Message published successfully. {'surface_temperature_celcius': 73, 'latitude': -37.4671, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 93, 'longitude': 145.9962}
# Message published successfully. {'surface_temperature_celcius': 50, 'latitude': -37.425, 'Senderid': 'TERRA', 'Datetime': '2019-05-24T15:46:13', 'confidence': 100, 'longitude': 148.107}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0ded0b1e0c0a> in <module>()
#      84     publish_message(Producer3, topic, data)
#      85     #time.sleep(3)
# ---> 86     time.sleep(1)
#      87
#      88
#
# KeyboardInterrupt:
